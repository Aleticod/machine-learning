# %% [markdown]
# # **DATASET DIABETES**

# %% [markdown]
# # **1. PASOS PREVIOS**

# %% [markdown]
# ## Importar librerias

# %%
# pandas: manejo de dataFrame
import pandas as pd
# sklearn: scikit-learn - Librería de python para Machine Learning
# Normalizar: permite escalar los datos a un rango de [0...1]

pd.options.mode.chained_assignment = None

# %% [markdown]
# ## Importacion de datos diabetes.csv

# %%
df_diabetes = pd.read_csv('diabetes.csv')
df_diabetes.head(10)
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia
# 0   40   Male       No        Yes                 No      Yes         No  \
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
# 5   55   Male      Yes        Yes                 No      Yes        Yes
# 6   57   Male      Yes        Yes                 No      Yes        Yes
# 7   66   Male      Yes        Yes                Yes      Yes         No
# 8   67   Male      Yes        Yes                 No      Yes        Yes
# 9   70   Male       No        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing
# 0             No              No     Yes           No             Yes  \
# ...

# %% [markdown]
# # **2. ELIMINACION DE DATOS FALTANTES**

# %% [markdown]
# ## Determinar si existen datos faltantes

# %%
# Visualizar informacion del dataset
df_diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 520 non-null    int64
#  1   Gender              520 non-null    object
#  2   Polyuria            520 non-null    object
#  3   Polydipsia          520 non-null    object
#  4   sudden weight loss  520 non-null    object
#  5   weakness            520 non-null    object
#  6   Polyphagia          520 non-null    object
#  7   Genital thrush      520 non-null    object
#  8   visual blurring     520 non-null    object
#  9   Itching             520 non-null    object
#  10  Irritability        520 non-null    object
#  11  delayed healing     520 non-null    object
#  12  partial paresis     520 non-null    object
#  13  muscle stiffness    520 non-null    object
#  14  Alopecia            520 non-null    object
# ...

# %%
# Numero de valors nulos por cada atributo
df_diabetes.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Polyuria              0
# Polydipsia            0
# sudden weight loss    0
# weakness              0
# Polyphagia            0
# Genital thrush        0
# visual blurring       0
# Itching               0
# Irritability          0
# delayed healing       0
# partial paresis       0
# muscle stiffness      0
# Alopecia              0
# Obesity               0
# class                 0
# dtype: int64

# %%
# Visualizar datos que tengas algun atributo nulo
nulos = df_diabetes[df_diabetes.isnull().any(axis=1)]
nulos
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Polyuria, Polydipsia, sudden weight loss, weakness, Polyphagia, Genital thrush, visual blurring, Itching, Irritability, delayed healing, partial paresis, muscle stiffness, Alopecia, Obesity, class]
# Index: []

# %%
# Numero de registros con valores nulos
print('numero de registros con valores nulos: ', len(nulos))
# Out:
# numero de registros con valores nulos:  0

# %% [markdown]
# ## **2.CONVERSION DE DATOS CATEGORICOS A NUMERICOS**

# %% [markdown]
# ## Revision de tipos de datos del dataset

# %%
# Ver los tipos de datos
df_diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 520 non-null    int64
#  1   Gender              520 non-null    object
#  2   Polyuria            520 non-null    object
#  3   Polydipsia          520 non-null    object
#  4   sudden weight loss  520 non-null    object
#  5   weakness            520 non-null    object
#  6   Polyphagia          520 non-null    object
#  7   Genital thrush      520 non-null    object
#  8   visual blurring     520 non-null    object
#  9   Itching             520 non-null    object
#  10  Irritability        520 non-null    object
#  11  delayed healing     520 non-null    object
#  12  partial paresis     520 non-null    object
#  13  muscle stiffness    520 non-null    object
#  14  Alopecia            520 non-null    object
# ...

# %% [markdown]
# ## Revision del atributo Polyuria

# %%
# Mostrar los valores existentes en la columna Polyuria
df_diabetes.Polyuria.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Numero de valores de dominio de Polyuria
df_diabetes.Polyuria.value_counts()
# Out:
# Polyuria
# No     262
# Yes    258
# Name: count, dtype: int64

# %%
# Verificacion de como se codificara automaticamente el atributo Polyuria
df_diabetes.Polyuria.astype('category').cat.codes
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 515    1
# 516    1
# 517    1
# 518    0
# 519    0
# Length: 520, dtype: int8

# %% [markdown]
# ### Implementacion de un modulo que convierte un atributo categorico a numerico utilizando las funciones **astype('category')** y **cat.codes**

# %%
def Categorico_a_numerico(atributo):
    # Convertir el atributo al tipo categorico
    atributo = atributo.astype('category')
    # Convertir el atributo categorico a numerico
    return atributo.astype('category').cat.codes

# %% [markdown]
# ## Convertir los atributos
# Gender
# Polyuria
# Polydipsia
# sudden weight loss
# weakness
# Polyphagia
# Genital thrush
# visual blurring
# Itching
# Irritability
# delayed healing
# partial paresis
# muscle stiffness
# Alopecia
# Obesity
# class

# %%
# Datos antes de la conversion
df_diabetes.head()
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia
# 0   40   Male       No        Yes                 No      Yes         No  \
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing
# 0             No              No     Yes           No             Yes  \
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class
# ...

# %%
# Convertir los datos categoricos a numerico
df_diabetes['Gender'] = Categorico_a_numerico(df_diabetes['Gender'])
df_diabetes['Polyuria'] = Categorico_a_numerico(df_diabetes['Polyuria'])
df_diabetes['Polydipsia'] = Categorico_a_numerico(df_diabetes['Polydipsia'])
df_diabetes['sudden weight loss'] = Categorico_a_numerico(df_diabetes['sudden weight loss'])
df_diabetes['weakness'] = Categorico_a_numerico(df_diabetes['weakness'])
df_diabetes['Polyphagia'] = Categorico_a_numerico(df_diabetes['Polyphagia'])
df_diabetes['Genital thrush'] = Categorico_a_numerico(df_diabetes['Genital thrush'])
df_diabetes['Itching'] = Categorico_a_numerico(df_diabetes['Itching'])
df_diabetes['delayed healing'] = Categorico_a_numerico(df_diabetes['delayed healing'])
df_diabetes['partial paresis'] = Categorico_a_numerico(df_diabetes['partial paresis'])
df_diabetes['muscle stiffness'] = Categorico_a_numerico(df_diabetes['muscle stiffness'])
df_diabetes['Alopecia'] = Categorico_a_numerico(df_diabetes['Alopecia'])
df_diabetes['Obesity'] = Categorico_a_numerico(df_diabetes['Obesity'])
df_diabetes['class'] = Categorico_a_numerico(df_diabetes['class'])

# %%
# Datos despues de la conversion
df_diabetes.head()
# Out:
#    Age  Gender  Polyuria  Polydipsia  sudden weight loss  weakness
# 0   40       1         0           1                   0         1  \
# 1   58       1         0           0                   0         1
# 2   41       1         1           0                   0         1
# 3   45       1         0           0                   1         1
# 4   60       1         1           1                   1         1
#
#    Polyphagia  Genital thrush visual blurring  Itching Irritability
# 0           0               0              No        1           No  \
# 1           0               0             Yes        0           No
# 2           1               0              No        1           No
# 3           1               1              No        1           No
# 4           1               0             Yes        1          Yes
#
#    delayed healing  partial paresis  muscle stiffness  Alopecia  Obesity
# 0                1                0                 1         1        1  \
# ...

# %% [markdown]
# ## **3. NORMALIZACION DE DATOS**

# %% [markdown]
# ## Implementar la normalizacion de datos por amplitud y distribucion

# %%
# Transformacion por amplitud [0..1]
def Normalizacion_Amplitud(atributo):
    return (atributo - atributo.min()) / (atributo.max() - atributo.min())

# %%
# Transformacion por distribucion [-1...1]
def Normalizacion_Distribucion(atributo):
    return (atributo - atributo.mean()) / (atributo.var())

# %% [markdown]
# ## Normalizar todos los datos por distribucion

# %%
# Atributos del datset
df_diabetes.columns
# Out:
# Index(['Age', 'Gender', 'Polyuria', 'Polydipsia', 'sudden weight loss',
#        'weakness', 'Polyphagia', 'Genital thrush', 'visual blurring',
#        'Itching', 'Irritability', 'delayed healing', 'partial paresis',
#        'muscle stiffness', 'Alopecia', 'Obesity', 'class'],
#       dtype='object')

# %%
# Normalizacion de datos por distribucion
df_diabetes['Age'] = Normalizacion_Distribucion(df_diabetes['Age'])
df_diabetes['Gender'] = Normalizacion_Distribucion(df_diabetes['Gender'])
df_diabetes['Polyuria'] = Normalizacion_Distribucion(df_diabetes['Polyuria'])
df_diabetes['Polydipsia'] = Normalizacion_Distribucion(df_diabetes['Polydipsia'])
df_diabetes['sudden weight loss'] = Normalizacion_Distribucion(df_diabetes['sudden weight loss'])
df_diabetes['weakness'] = Normalizacion_Distribucion(df_diabetes['weakness'])
df_diabetes['Polyphagia'] = Normalizacion_Distribucion(df_diabetes['Polyphagia'])
df_diabetes['Genital thrush'] = Normalizacion_Distribucion(df_diabetes['Genital thrush'])
df_diabetes['Itching'] = Normalizacion_Distribucion(df_diabetes['Itching'])
df_diabetes['delayed healing'] = Normalizacion_Distribucion(df_diabetes['delayed healing'])
df_diabetes['partial paresis'] = Normalizacion_Distribucion(df_diabetes['partial paresis'])
df_diabetes['muscle stiffness'] = Normalizacion_Distribucion(df_diabetes['muscle stiffness'])
df_diabetes['Alopecia'] = Normalizacion_Distribucion(df_diabetes['Alopecia'])
df_diabetes['Obesity'] = Normalizacion_Distribucion(df_diabetes['Obesity'])
df_diabetes['class'] = Normalizacion_Distribucion(df_diabetes['class'])

# %%
# Datos despues de la normalizacion por distribucion
df_diabetes.head()
# Out:
#         Age    Gender  Polyuria  Polydipsia  sudden weight loss  weakness
# 0 -0.054375  1.582317 -1.980916    2.227468           -1.712871  1.701639  \
# 1  0.067529  1.582317 -1.980916   -1.808362           -1.712871  1.701639
# 2 -0.047602  1.582317  2.011628   -1.808362           -1.712871  1.701639
# 3 -0.020513  1.582317 -1.980916   -1.808362            2.391705  1.701639
# 4  0.081073  1.582317  2.011628    2.227468            2.391705  1.701639
#
#    Polyphagia  Genital thrush visual blurring   Itching Irritability
# 0   -1.833922       -1.284653              No  2.051383           No  \
# 1   -1.833922       -1.284653             Yes -1.943820           No
# 2    2.189873       -1.284653              No  2.051383           No
# 3    2.189873        4.474138              No  2.051383           No
# 4    2.189873       -1.284653             Yes  2.051383          Yes
#
#    delayed healing  partial paresis  muscle stiffness  Alopecia   Obesity
# ...

# %% [markdown]
# # **4. GRABACION DE DATOS PRE-PROCESADOS**

# %%
# Guardar el procesamiento de datos en un archivo csv
df_diabetes.to_csv('datos_diabetes_norm.csv', sep=',', header=True, index=False)
